# %%
# %%capture
# %run neural_net_feed_forward_gradient.py

# %%
nn = neural_net_feed_forward_gradient()

# %%
nn.train()
# Out:
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3320>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3320>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3320>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3320>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# accuracy for pass 0: 85.7%
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF32B0>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF32B0>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF32B0>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF32B0>
# <PIL.Image.Image image mode=L size=290x28 at 0x11DBF3208>
# ...
